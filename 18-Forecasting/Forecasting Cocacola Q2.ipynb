# %% [markdown]
# # Cocacola Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from pandas import read_csv
from matplotlib import pyplot
from pandas import DataFrame
from pandas.plotting import lag_plot
from statsmodels.graphics.tsaplots import plot_acf
import seaborn as sns

# %%
cocacola=pd.read_excel(r"C:\Users\Shivam\Downloads\CocaCola_Sales_Rawdata.xlsx",header=0, index_col=0)
cocacola.head(10)
# Out:
#                Sales
# Quarter
# Q1_86    1734.827000
# Q2_86    2244.960999
# Q3_86    2533.804993
# Q4_86    2154.962997
# Q1_87    1547.818996
# Q2_87    2104.411995
# Q3_87    2014.362999
# Q4_87    1991.746998
# Q1_88    1869.049999
# Q2_88    2313.631996

# %%
cocacola.plot()
# Out:
# <AxesSubplot:>

# %%
cocacola.boxplot()
# Out:
# <AxesSubplot:>

# %%
lag_plot(cocacola)
pyplot.show()

# %%
plot_acf(cocacola,lags=30)

# %%
pyplot.subplot(211)
pyplot.plot(cocacola)
pyplot.subplot(212)
pyplot.hist(cocacola)
# Out:
# (array([ 4., 10.,  5.,  4.,  6.,  3.,  3.,  4.,  0.,  3.]),
#  array([1547.81899643, 1918.33709679, 2288.85519714, 2659.3732975 ,
#         3029.89139786, 3400.40949821, 3770.92759857, 4141.44569893,
#         4511.96379929, 4882.48189964, 5253.        ]),
#  <BarContainer object of 10 artists>)

# %%
from pandas import DataFrame
from numpy import sqrt

# %%
dataframe = DataFrame(cocacola.values)
dataframe.columns = ['Sales']
dataframe['Sales'] = sqrt(dataframe['Sales'])

# %%
pyplot.subplot(211)
pyplot.plot(dataframe['Sales'])
pyplot.subplot(212)
pyplot.hist(dataframe['Sales'])
# Out:
# (array([2., 5., 8., 4., 4., 5., 4., 4., 3., 3.]),
#  array([6.27234652, 6.49644954, 6.72055255, 6.94465557, 7.16875859,
#         7.39286161, 7.61696462, 7.84106764, 8.06517066, 8.28927368,
#         8.51337669]),
#  <BarContainer object of 10 artists>)

# %%
from numpy import log
dataframe = DataFrame(cocacola.values)
dataframe.columns = ['Sales']
dataframe['Sales'] = log(dataframe['Sales'])
pyplot.subplot(211)
pyplot.plot(dataframe['Sales'])
pyplot.subplot(212)
pyplot.hist(dataframe['Sales'])
# Out:
# (array([2., 2., 9., 4., 5., 4., 6., 3., 4., 3.]),
#  array([1.83615053, 1.86669934, 1.89724816, 1.92779697, 1.95834578,
#         1.98889459, 2.01944341, 2.04999222, 2.08054103, 2.11108984,
#         2.14163866]),
#  <BarContainer object of 10 artists>)

# %%
from sklearn.preprocessing import MinMaxScaler
data1=pd.read_excel(r"C:\Users\Shivam\Downloads\CocaCola_Sales_Rawdata.xlsx")
data1
# Out:
#    Quarter        Sales
# 0    Q1_86  1734.827000
# 1    Q2_86  2244.960999
# 2    Q3_86  2533.804993
# 3    Q4_86  2154.962997
# 4    Q1_87  1547.818996
# 5    Q2_87  2104.411995
# 6    Q3_87  2014.362999
# 7    Q4_87  1991.746998
# 8    Q1_88  1869.049999
# 9    Q2_88  2313.631996
# 10   Q3_88  2128.320000
# 11   Q4_88  2026.828999
# 12   Q1_89  1910.603996
# 13   Q2_89  2331.164993
# 14   Q3_89  2206.549995
# 15   Q4_89  2173.967995
# 16   Q1_90  2148.278000
# 17   Q2_90  2739.307999
# 18   Q3_90  2792.753998
# 19   Q4_90  2556.009995
# 20   Q1_91  2480.973999
# 21   Q2_91  3039.522995
# 22   Q3_91  3172.115997
# 23   Q4_91  2879.000999
# 24   Q1_92  2772.000000
# 25   Q2_92  3550.000000
# 26   Q3_92  3508.000000
# 27   Q4_92  3243.859993
# 28   Q1_93  3056.000000
# 29   Q2_93  3899.000000
# 30   Q3_93  3629.000000
# 31   Q4_93  3373.000000
# 32   Q1_94  3352.000000
# 33   Q2_94  4342.000000
# 34   Q3_94  4461.000000
# 35   Q4_94  4017.000000
# 36   Q1_95  3854.000000
# 37   Q2_95  4936.000000
# 38   Q3_95  4895.000000
# 39   Q4_95  4333.000000
# 40   Q1_96  4194.000000
# 41   Q2_96  5253.000000

# %%
arr=data1.values

# %%
X = arr[:,0]   
Y = arr[:,1].reshape(-1, 1)

from numpy import set_printoptions
scaler = MinMaxScaler(feature_range=(0,1))
rescaledX = scaler.fit_transform(Y)
set_printoptions(precision=2)
print(rescaledX[:10,:])
# Out:
# [[0.05]
#  [0.19]
#  [0.27]
#  [0.16]
#  [0.  ]
#  [0.15]
#  [0.13]
#  [0.12]
#  [0.09]
#  [0.21]]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler().fit(Y)
rescaledX = scaler.transform(Y)
set_printoptions(precision=3)
print(rescaledX[0:5,:])
# Out:
# [[-1.304]
#  [-0.776]
#  [-0.477]
#  [-0.869]
#  [-1.497]]

# %%
cocacola=pd.read_excel(r"C:\Users\Shivam\Downloads\CocaCola_Sales_Rawdata.xlsx")
cocacola
# Out:
#    Quarter        Sales
# 0    Q1_86  1734.827000
# 1    Q2_86  2244.960999
# 2    Q3_86  2533.804993
# 3    Q4_86  2154.962997
# 4    Q1_87  1547.818996
# 5    Q2_87  2104.411995
# 6    Q3_87  2014.362999
# 7    Q4_87  1991.746998
# 8    Q1_88  1869.049999
# 9    Q2_88  2313.631996
# 10   Q3_88  2128.320000
# 11   Q4_88  2026.828999
# 12   Q1_89  1910.603996
# 13   Q2_89  2331.164993
# 14   Q3_89  2206.549995
# 15   Q4_89  2173.967995
# 16   Q1_90  2148.278000
# 17   Q2_90  2739.307999
# 18   Q3_90  2792.753998
# 19   Q4_90  2556.009995
# 20   Q1_91  2480.973999
# 21   Q2_91  3039.522995
# 22   Q3_91  3172.115997
# 23   Q4_91  2879.000999
# 24   Q1_92  2772.000000
# 25   Q2_92  3550.000000
# 26   Q3_92  3508.000000
# 27   Q4_92  3243.859993
# 28   Q1_93  3056.000000
# 29   Q2_93  3899.000000
# 30   Q3_93  3629.000000
# 31   Q4_93  3373.000000
# 32   Q1_94  3352.000000
# 33   Q2_94  4342.000000
# 34   Q3_94  4461.000000
# 35   Q4_94  4017.000000
# 36   Q1_95  3854.000000
# 37   Q2_95  4936.000000
# 38   Q3_95  4895.000000
# 39   Q4_95  4333.000000
# 40   Q1_96  4194.000000
# 41   Q2_96  5253.000000

# %%
quarter=['Q1','Q2','Q3','Q4']
n=cocacola['Quarter'][0]
n[0:2]
cocacola['quarter']=0

# %%
for i in range(42):
    n=cocacola['Quarter'][i]
    cocacola['quarter'][i]=n[0:2]

# %%
dummy=pd.DataFrame(pd.get_dummies(cocacola['quarter']))
cocodata=pd.concat((cocacola,dummy),axis=1)

# %%
cocodata.head(10)
# Out:
#   Quarter        Sales quarter  Q1  Q2  Q3  Q4
# 0   Q1_86  1734.827000      Q1   1   0   0   0
# 1   Q2_86  2244.960999      Q2   0   1   0   0
# 2   Q3_86  2533.804993      Q3   0   0   1   0
# 3   Q4_86  2154.962997      Q4   0   0   0   1
# 4   Q1_87  1547.818996      Q1   1   0   0   0
# 5   Q2_87  2104.411995      Q2   0   1   0   0
# 6   Q3_87  2014.362999      Q3   0   0   1   0
# 7   Q4_87  1991.746998      Q4   0   0   0   1
# 8   Q1_88  1869.049999      Q1   1   0   0   0
# 9   Q2_88  2313.631996      Q2   0   1   0   0

# %%
t= np.arange(1,43)
cocodata['t']=t
cocodata['t_square']=cocodata['t']*cocodata['t']

# %%
log_Sales=np.log(cocodata['Sales'])
cocodata['log_Sales']=log_Sales

# %%
cocodata.head(10)
# Out:
#   Quarter        Sales quarter  Q1  Q2  Q3  Q4   t  t_square  log_Sales
# 0   Q1_86  1734.827000      Q1   1   0   0   0   1         1   7.458663
# 1   Q2_86  2244.960999      Q2   0   1   0   0   2         4   7.716443
# 2   Q3_86  2533.804993      Q3   0   0   1   0   3         9   7.837477
# 3   Q4_86  2154.962997      Q4   0   0   0   1   4        16   7.675529
# 4   Q1_87  1547.818996      Q1   1   0   0   0   5        25   7.344602
# 5   Q2_87  2104.411995      Q2   0   1   0   0   6        36   7.651791
# 6   Q3_87  2014.362999      Q3   0   0   1   0   7        49   7.608058
# 7   Q4_87  1991.746998      Q4   0   0   0   1   8        64   7.596767
# 8   Q1_88  1869.049999      Q1   1   0   0   0   9        81   7.533186
# 9   Q2_88  2313.631996      Q2   0   1   0   0  10       100   7.746574

# %%
data1.Sales.plot()
# Out:
# <AxesSubplot:>

# %%
Train=cocodata.head(35)
Test=cocodata.tail(7)

# %%
import statsmodels.formula.api as smf

# %%
linear= smf.ols('Sales~t',data=Train).fit()
predlin=pd.Series(linear.predict(pd.DataFrame(Test['t'])))
rmselin=np.sqrt((np.mean(np.array(Test['Sales'])-np.array(predlin))**2))
rmselin
# Out:
# 465.8922910898691

# %%
quad=smf.ols('Sales~t+t_square',data=Train).fit()
predquad=pd.Series(quad.predict(pd.DataFrame(Test[['t','t_square']])))
rmsequad=np.sqrt(np.mean((np.array(Test['Sales'])-np.array(predquad))**2))
rmsequad
# Out:
# 511.81173194173283

# %%
expo=smf.ols('log_Sales~t',data=Train).fit()
predexp=pd.Series(expo.predict(pd.DataFrame(Test['t'])))
rmseexpo=np.sqrt(np.mean((np.array(Test['Sales'])-np.array(np.exp(predexp)))**2))
rmseexpo
# Out:
# 493.348648484222

# %%
additive= smf.ols('Sales~ Q1+Q2+Q3+Q4',data=Train).fit()
predadd=pd.Series(additive.predict(pd.DataFrame(Test[['Q1','Q2','Q3','Q4']])))
rmseadd=np.sqrt(np.mean((np.array(Test['Sales'])-np.array(predadd))**2))
rmseadd
# Out:
# 1861.870416425175

# %%
addlinear= smf.ols('Sales~t+Q1+Q2+Q3+Q4',data=Train).fit()
predaddlinear=pd.Series(addlinear.predict(pd.DataFrame(Test[['t','Q1','Q2','Q3','Q4']])))
rmseaddlinear=np.sqrt(np.mean((np.array(Test['Sales'])-np.array(predaddlinear))**2))
rmseaddlinear
# Out:
# 559.6933951413088

# %%
addquad=smf.ols('Sales~t+t_square+Q1+Q2+Q3+Q4',data=Train).fit()
predaddquad=pd.Series(addquad.predict(pd.DataFrame(Test[['t','t_square','Q1','Q2','Q3','Q4']])))
rmseaddquad=np.sqrt(np.mean((np.array(Test['Sales'])-np.array(predaddquad))**2))
rmseaddquad
# Out:
# 309.4641395163693

# %%
mulsea=smf.ols('log_Sales~Q1+Q2+Q3+Q4',data=Train).fit()
predmul= pd.Series(mulsea.predict(pd.DataFrame(Test[['Q1','Q2','Q3','Q4']])))
rmsemul= np.sqrt(np.mean((np.array(Test['Sales'])-np.array(np.exp(predmul)))**2))
rmsemul
# Out:
# 1938.9332351966193

# %%
mullin= smf.ols('log_Sales~t+Q1+Q2+Q3+Q4',data=Train).fit()
predmullin= pd.Series(mullin.predict(pd.DataFrame(Test[['t','Q1','Q2','Q3','Q4']])))
rmsemulin=np.sqrt(np.mean((np.array(Test['Sales'])-np.array(np.exp(predmullin)))**2))
rmsemulin
# Out:
# 339.1874666994836

# %%
mul_quad= smf.ols('log_Sales~t+t_square+Q1+Q2+Q3+Q4',data=Train).fit()
pred_mul_quad= pd.Series(mul_quad.predict(Test[['t','t_square','Q1','Q2','Q3','Q4']]))
rmse_mul_quad=np.sqrt(np.mean((np.array(Test['Sales'])-np.array(np.exp(pred_mul_quad)))**2))
rmse_mul_quad
# Out:
# 673.411623571175

# %%
Table={'Model':pd.Series(['rmselin','rmsequad','rmseexpo','rmseadd','rmseaddlinear','rmseaddquad','rmsemul','rmsemulin','rmse_mul_quad']),'Values':pd.Series([rmselin,rmsequad,rmseexpo,rmseadd,rmseaddlinear,rmseaddquad,rmsemul,rmsemulin,rmse_mul_quad])}
RMSE_Table=pd.DataFrame(Table)
RMSE_Table.T
# Out:
#                  0           1           2            3              4  \
# Model      rmselin    rmsequad    rmseexpo      rmseadd  rmseaddlinear
# Values  465.892291  511.811732  493.348648  1861.870416     559.693395
#
#                   5            6           7              8
# Model   rmseaddquad      rmsemul   rmsemulin  rmse_mul_quad
# Values    309.46414  1938.933235  339.187467     673.411624

# %%
pred=cocodata
final_pred= smf.ols('log_Sales~t+Q1+Q2+Q3+Q4',data=data1).fit()

# %%
pred_new = pd.Series(mullin.predict(pred))
pred_new

pred["forecasted_Sales"] = np.exp(pd.Series(pred_new))
pred
# Out:
#    Quarter        Sales quarter  Q1  Q2  Q3  Q4   t  t_square  log_Sales  \
# 0    Q1_86  1734.827000      Q1   1   0   0   0   1         1   7.458663
# 1    Q2_86  2244.960999      Q2   0   1   0   0   2         4   7.716443
# 2    Q3_86  2533.804993      Q3   0   0   1   0   3         9   7.837477
# 3    Q4_86  2154.962997      Q4   0   0   0   1   4        16   7.675529
# 4    Q1_87  1547.818996      Q1   1   0   0   0   5        25   7.344602
# 5    Q2_87  2104.411995      Q2   0   1   0   0   6        36   7.651791
# 6    Q3_87  2014.362999      Q3   0   0   1   0   7        49   7.608058
# 7    Q4_87  1991.746998      Q4   0   0   0   1   8        64   7.596767
# 8    Q1_88  1869.049999      Q1   1   0   0   0   9        81   7.533186
# 9    Q2_88  2313.631996      Q2   0   1   0   0  10       100   7.746574
# 10   Q3_88  2128.320000      Q3   0   0   1   0  11       121   7.663088
# 11   Q4_88  2026.828999      Q4   0   0   0   1  12       144   7.614228
# 12   Q1_89  1910.603996      Q1   1   0   0   0  13       169   7.555175
# 13   Q2_89  2331.164993      Q2   0   1   0   0  14       196   7.754123
# 14   Q3_89  2206.549995      Q3   0   0   1   0  15       225   7.699185
# 15   Q4_89  2173.967995      Q4   0   0   0   1  16       256   7.684309
# 16   Q1_90  2148.278000      Q1   1   0   0   0  17       289   7.672422
# 17   Q2_90  2739.307999      Q2   0   1   0   0  18       324   7.915461
# 18   Q3_90  2792.753998      Q3   0   0   1   0  19       361   7.934783
# 19   Q4_90  2556.009995      Q4   0   0   0   1  20       400   7.846203
# 20   Q1_91  2480.973999      Q1   1   0   0   0  21       441   7.816407
# 21   Q2_91  3039.522995      Q2   0   1   0   0  22       484   8.019456
# 22   Q3_91  3172.115997      Q3   0   0   1   0  23       529   8.062154
# 23   Q4_91  2879.000999      Q4   0   0   0   1  24       576   7.965199
# 24   Q1_92  2772.000000      Q1   1   0   0   0  25       625   7.927324
# 25   Q2_92  3550.000000      Q2   0   1   0   0  26       676   8.174703
# 26   Q3_92  3508.000000      Q3   0   0   1   0  27       729   8.162801
# 27   Q4_92  3243.859993      Q4   0   0   0   1  28       784   8.084519
# 28   Q1_93  3056.000000      Q1   1   0   0   0  29       841   8.024862
# 29   Q2_93  3899.000000      Q2   0   1   0   0  30       900   8.268475
# 30   Q3_93  3629.000000      Q3   0   0   1   0  31       961   8.196712
# 31   Q4_93  3373.000000      Q4   0   0   0   1  32      1024   8.123558
# 32   Q1_94  3352.000000      Q1   1   0   0   0  33      1089   8.117312
# 33   Q2_94  4342.000000      Q2   0   1   0   0  34      1156   8.376090
# 34   Q3_94  4461.000000      Q3   0   0   1   0  35      1225   8.403128
# 35   Q4_94  4017.000000      Q4   0   0   0   1  36      1296   8.298291
# 36   Q1_95  3854.000000      Q1   1   0   0   0  37      1369   8.256867
# 37   Q2_95  4936.000000      Q2   0   1   0   0  38      1444   8.504311
# 38   Q3_95  4895.000000      Q3   0   0   1   0  39      1521   8.495970
# 39   Q4_95  4333.000000      Q4   0   0   0   1  40      1600   8.374015
# 40   Q1_96  4194.000000      Q1   1   0   0   0  41      1681   8.341410
# 41   Q2_96  5253.000000      Q2   0   1   0   0  42      1764   8.566555
#
#     forecasted_Sales
# 0        1562.623703
# 1        1989.391852
# 2        1977.111562
# 3        1819.954172
# 4        1710.868669
# 5        2178.124000
# 6        2164.678688
# 7        1992.611891
# 8        1873.177526
# 9        2384.761028
# 10       2370.040169
# 11       2181.649521
# 12       2050.884506
# 13       2611.001559
# 14       2594.884144
# 15       2388.621013
# 16       2245.450417
# 17       2858.705364
# 18       2841.058902
# 19       2615.227739
# 20       2458.474653
# 21       3129.908648
# 22       3110.588078
# 23       2863.332478
# 24       2691.708342
# 25       3426.840789
# 26       3405.687290
# 27       3134.974733
# 28       2947.068740
# 29       3751.942664
# 30       3728.782349
# 31       3432.387489
# 32       3226.654993
# 33       4107.886716
# 34       4082.529199
# 35       3758.015576
# 36       3532.765388
# 37       4497.598919
# 38       4469.835753
# 39       4114.535760
# 40       3867.916252
# 41       4924.282834
